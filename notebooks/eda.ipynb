# %% [markdown]
# # Exploratory Data Analysis
# ___
# Since **01/02/2021** the script `../yt_trends_mining/trends.py` uses the [YouTube Data API](https://developers.google.com/youtube/v3) to store various video and channel information as a CSV file for all recent videos on a country's [YouTube Trends](https://www.youtube.com/feed/trending) page in a [Google Cloud Storage](https://cloud.google.com/storage) bucket. The script runs once a day at **17:00 UTC** and collects the information for the following countries: ["US", "BR", "RU", "JP", "IN", "GB", "DE", "FR", "CA", "AU"] (ISO 3166). The `20210201_US.csv` shows the data structure of the CSV file.

# %%
# Import libraries
import os
import pandas as pd
import plotly.express as px
from emoji import EMOJI_DATA
from utils import category_dict, extract_emojis, get_data_from_gcs, get_seconds, print_size

# Set Pandas options
pd.set_option("display.float_format", lambda x: "%.3f" % x)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', 100)

# Add Goggle Cloud Credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../keys/credentials.json"

# List of country codes
countries = ["US", "BR", "RU", "JP", "IN", "GB", "DE", "FR", "CA", "AU"]

# Dataframe & dictionary to compare the different countries
ANALYSIS = pd.DataFrame({"countries": countries})
COUNTRIES = {}

# Want to show plots?
show_plot = False

# %% [markdown]
# First, all CSVs for a country are downloaded and stored in a subfolder under `../data/subfolder`. If data has already been downloaded and only a few days are missing then only the missing CSV will be downloaded. Afterwards all CSV are read into Pandas DataFrames.

# %%
# Download all country CSVs from GCS & print the subfolder size
for country in countries:
    # get_data_from_gcs(country)
    print_size(f"../data/{country}/")
# Out:
# Size of all csvs in ../data/US/: 63.124545 MB
# Size of all csvs in ../data/BR/: 55.19159 MB
# Size of all csvs in ../data/RU/: 87.14633 MB
# Size of all csvs in ../data/JP/: 84.358006 MB
# Size of all csvs in ../data/IN/: 64.38731 MB
# Size of all csvs in ../data/GB/: 61.367029 MB
# Size of all csvs in ../data/DE/: 71.116751 MB
# Size of all csvs in ../data/FR/: 58.080379 MB
# Size of all csvs in ../data/CA/: 63.001809 MB
# Size of all csvs in ../data/AU/: 60.784615 MB

# %%
# Concatenate all country CSVs in one Dataframe & wrangle it
for country in countries:
    df = pd.concat([pd.read_csv(f"../data/{country}/{file}") for file in os.listdir(f"../data/{country}") if file.endswith(".csv")])
    df = df.assign(categoryNames=lambda x: x["categoryIds"].map(category_dict))
    df["today"] = pd.to_datetime(df["today"]).dt.normalize()
    df["publishedAt"] = pd.to_datetime(df["publishedAt"]).dt.normalize()
    df["duration_in_s"] = df["durations"].apply(get_seconds)

    if "Unnamed: 0" in df.columns:
        df.drop(columns=["Unnamed: 0"], inplace=True)
    
    COUNTRIES[country] = df

# Basic informations
international = pd.concat(COUNTRIES.values(), ignore_index=True)
min_date = international["today"].min().strftime("%Y-%m-%d")
max_date = international["today"].max().strftime("%Y-%m-%d")
print(f"The data set covers the period from {min_date} to {max_date} and consists of {international.shape[0]} rows and {international.shape[1]} columns.")
# Out:
# The data set covers the period from 2021-02-01 to 2023-03-17 and consists of 385463 rows and 26 columns.

# %%
# First 3 rows of the "US" dataframe
COUNTRIES["US"].head(3)
# Out:
#    sequence                     today     videoIds               publishedAt  \
# 0         1 2022-05-06 00:00:00+00:00  p38WgakuYDo 2022-05-06 00:00:00+00:00
# 1         2 2022-05-06 00:00:00+00:00  0NzlbBmkM3E 2022-05-05 00:00:00+00:00
# 2         3 2022-05-06 00:00:00+00:00  Wg86eQkdudI 2022-05-05 00:00:00+00:00
#
#                                                         titles  \
# 0  Bad Bunny - Moscow Mule (Official Video) | Un Verano Sin Ti
# 1                         A$AP Rocky - D.M.B. (Official Video)
# 2      House of the Dragon | Official Teaser Trailer | HBO Max
#
#                  channelIds     channelTitles  \
# 0  UCmBA_wu8xGg1OfOkfW13Q0Q         Bad Bunny
# 1  UCHE7rAi1Fw1CBmQXFtvJmrw  LIVELOVEASAPVEVO
# 2  UCx-KWLTKlB83hDI6UKECtJQ           HBO Max
#
#                                        thumbnails  categoryIds  \
# 0  https://i.ytimg.com/vi/p38WgakuYDo/default.jpg           10
# 1  https://i.ytimg.com/vi/0NzlbBmkM3E/default.jpg           10
# 2  https://i.ytimg.com/vi/Wg86eQkdudI/default.jpg            1
#
#                                                                                           descriptions  \
# 0  Bad Bunny - Moscow Mule (Official Video) | Un Verano Sin Ti\nUn Verano Sin Ti https://www.unvera...
# 1  A$AP ROCKY’S “D.M.B.”: https://AsapRocky.lnk.to/DMB\n\nOFFICIAL VIDEO FOR ”D.M.B.” BY A$AP ROCKY...
# 2  History does not remember blood. It remembers names. August 21. #HouseoftheDragon\n\nAbout HBO M...
#
#                                                                                                   tags  \
# 0  ['Bad', 'Bunny', 'Bad Bunny', 'YHLQMDLG', 'EUTDM', 'UnVeranoSinTi', 'Un Verano Sin Ti', 'UVST', ...
# 1  ['ASAP Rocky', 'rihanna', 'asap rocky music', 'asap rocky new music', 'rih rih', 'fenty', 'rocky...
# 2  ['hbo', 'hbo max', 'hbo max movie', 'hbo max series', 'hbo youtube', 'hbo max youtube', 'hbo max...
#
#         views       likes  dislikes  comments durations   regionRestrictions  \
# 0 8231777.000 1169179.000       NaN 43117.000   PT4M13S                  NaN
# 1 3366590.000  341304.000       NaN 16167.000   PT4M53S  {'blocked': ['RU']}
# 2 5057320.000   87868.000       NaN  6410.000   PT1M44S                  NaN
#
#   relevantTopicIds    channelPublishedAt channelCountry  channelViewCount  \
# 0              NaN  2014-06-09T02:50:42Z             PR       19573859774
# 1              NaN  2011-12-07T23:05:46Z            NaN        1736059684
# 2              NaN  2019-07-03T14:47:23Z             US         601805114
#
#    channelSubscriberCount  channelVideoCount  \
# 0            39000000.000                120
# 1             1440000.000                 80
# 2             1380000.000               1186
#
#                           channelTopicIds     categoryNames  duration_in_s
# 0  ['/m/0glt670', '/m/04rlf', '/m/0g293']             Music            253
# 1              ['/m/04rlf', '/m/0glt670']             Music            293
# 2    ['/m/02jjt', '/m/02vxn', '/m/0f2f9']  Film & Animation            104

# %% [markdown]
# The dataframes still contains the raw data. For example, a video may still currently be included multiple times if it was on the trending page for several days. Therefore, it is necessary that the data is further aggregated for each specific analysis.
#
# <br>
#
# ## 1. Daily distribution of video categories
# ___

# %%
top3_categories = {}
for country in countries:
    df = COUNTRIES[country]

    # Want to see the plots?
    if show_plot:
        px.bar(
            df.groupby(["today", "categoryNames"])
            .agg(count=("categoryNames", "count"))
            .reset_index(),
            x="today",
            y="count",
            color="categoryNames",
            labels={"count": "Number of videos", "today": "Date", "categoryNames": "Video category"},
            title=f"{country}: Number of videos per category for each day",
            color_discrete_map={
                "Film & Animation": "brown",
                "Autos & Vehicles": "lightblue",
                "Music": "green",
                "Pets & Animals": "black",
                "Sports": "grey",
                "Travel & Events": "yellow",
                "Gaming": "magenta",
                "People & Blogs": "orange",
                "Comedy": "purple",
                "Entertainment": "blue",
                "News & Politics": "red",
                "Howto & Style": "pink",
                "Education": "olive",
                "Science & Technology": "cyan",
                "Nonprofits & Activism": "lightgreen"
            }
        ).update_layout(height=600, width=1200).show()

        fig = px.bar(
            df["categoryNames"].value_counts().sort_values(ascending=True).reset_index(),
            x="categoryNames",
            y="index",
            orientation="h",
            title=f"{country}: Number of videos per category",
            labels={
                "categoryNames": "Number of videos",
                "index": "Category"
            }
        ).update_layout(height=400, width=1200).show()

    # What are the top 3 video categories?
    top3 = (
        df["categoryNames"]
        .value_counts()
        .sort_values(ascending=False)
        .reset_index()
        .assign(percentage=lambda x: (x["categoryNames"] / x["categoryNames"].sum()) * 100)
        .head(3)
        .drop(columns=["categoryNames"])
        .set_index("index")
        .to_dict(orient="index")
    )
    top3 = {k: round(v["percentage"], 1) for k, v in top3.items()}
    top3_categories.update({country: top3})

# Store & show results
ANALYSIS = ANALYSIS.assign(top3_categories=lambda x: x["countries"].map(top3_categories))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}

# %% [markdown]
# <br>
#
# ## 2. Country of origin of the content creator
# ___

# %%
origin_share = {}
for country in countries:
    df = COUNTRIES[country]

    # Group data
    origin = (
        df["channelCountry"]
        .value_counts()
        .sort_values(ascending=False)
        .reset_index()
        .assign(percentage=lambda x: (x["channelCountry"] / x["channelCountry"].sum()) * 100)
    )

    # Want to see the plot?
    if show_plot:
        origin["index"] = origin["index"].where(origin["index"].isin(origin["index"].head(5)), "Other")
        fig = (
            px.pie(
                origin,
                values="percentage",
                names="index",
                title=f"{country}: Origin countries of the content creator")
            .update_layout(height=500, width=500)
            .update_traces(hole=.4, textposition='inside', textinfo='percent+label')
            .update_layout(annotations=[dict(text=country, x=0.50, y=0.5, font_size=25, showarrow=False)])
            .show()
        )

    # What is the percentage of videos from the country of origin?
    origin_country = origin[origin["index"] == country]
    origin_share.update({country: round(origin_country["percentage"].values[0], 1)})

# Store & show results
ANALYSIS = ANALYSIS.assign(origin_share=lambda x: x["countries"].map(origin_share))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories  \
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}
#
#    origin_share
# 0        76.700
# 1        91.800
# 2        67.600
# 3        95.200
# 4        92.100
# 5        41.300
# 6        72.000
# 7        86.900
# 8         7.000
# 9        16.100

# %% [markdown]
# <br>
#
# ## 3. Video title analysis
# ___

# %%
title_length = {}
title_upper = {}
emoji_share = {}
emoji_top3 = {}
for country in countries:
    df = COUNTRIES[country]

    # Group data
    data = (
        df.groupby(["channelTitles", "titles", "publishedAt", "categoryNames"])
            .agg(todays_count=("today", "count"))
            .sort_values("todays_count", ascending=False)
            .reset_index()
    )

    # How long is the average title?
    data["title_length"] = data["titles"].apply(lambda x: len(x))
    title_length.update({country: round(data["title_length"].mean(), 1)})

    # What percentage of video titles have capital letters?
    data["title_upper"] = data["titles"].apply(lambda x: sum(1 for c in x if c.isupper()))
    data["title_upper"] = data["title_upper"] / data["title_length"]
    title_upper.update({country: round(data["title_upper"].mean() * 100, 1)})

    # What percentage of videos have emojis in the title?
    data["emoji_in_title"] = data["titles"].apply(lambda x: sum(1 for c in x if c in EMOJI_DATA))
    emoji_share.update({country: round((data[data["emoji_in_title"] >= 1].shape[0] / data.shape[0]) * 100, 1)})

    # What are the 10 most popular emojis?
    data["emojis"] = data["titles"].apply(extract_emojis)
    emojis = data[data["emoji_in_title"] >= 1].copy()
    emojis = emojis.assign(emojis=lambda x: x["emojis"].str.split("")).explode("emojis")
    emojis = emojis["emojis"].value_counts()[1:].head(3).to_dict()
    emoji_top3.update({country: emojis})

# Store & show results
ANALYSIS = ANALYSIS.assign(title_length=lambda x: x["countries"].map(title_length))
ANALYSIS = ANALYSIS.assign(title_upper=lambda x: x["countries"].map(title_upper))
ANALYSIS = ANALYSIS.assign(emoji_share=lambda x: x["countries"].map(emoji_share))
ANALYSIS = ANALYSIS.assign(emoji_top3=lambda x: x["countries"].map(emoji_top3))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories  \
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}
#
#    origin_share  title_length  title_upper  emoji_share  \
# 0        76.700        50.100       22.600        4.000
# 1        91.800        55.000       45.100        9.000
# 2        67.600        57.800       30.700        8.700
# 3        95.200        37.900        8.000        4.000
# 4        92.100        68.400       16.600       26.000
# 5        41.300        52.400       23.100        5.600
# 6        72.000        55.700       22.700       15.600
# 7        86.900        51.800       29.800       10.800
# 8         7.000        50.600       22.500        4.600
# 9        16.100        50.000       22.800        4.900
#
#                         emoji_top3
# 0      {'😂': 86, '😳': 64, '😱': 52}
# 1   {'😱': 260, '😂': 226, '🔥': 166}
# 2   {'😱': 512, '⚡': 322, '🔥': 263}
# 3     {'‼': 128, '🔥': 60, '⁉': 59}
# 4  {'😂': 1323, '❤': 620, '🤣': 574}
# 5    {'🔥': 107, '😂': 103, '🤯': 79}
# 6   {'🔥': 487, '😂': 451, '😱': 447}
# 7   {'🔥': 154, '😂': 153, '😱': 153}
# 8     {'😂': 119, '😳': 73, '🔥': 60}
# 9      {'😂': 97, '🔥': 70, '😳': 57}

# %%
# What are the 10 most popular international emojis?
international = pd.concat(COUNTRIES.values(), ignore_index=True)
international["emojis"] = international["titles"].apply(extract_emojis)
international = international.assign(emojis=lambda x: x["emojis"].str.split("")).explode("emojis")
top10_emojis = international["emojis"].value_counts()[1:].head(10).to_dict()

# Want to see the plot?
if show_plot:
    fig = px.bar(
        pd.DataFrame.from_dict(top10_emojis, orient="index").reset_index(),
        x="index",
        y=0,
        orientation="v",
        title="10 most popular international emojis",
        labels={
            "index": "Emoji",
            0: "Number of videos"
        }
    ).update_layout(height=500, width=800).show()

top10_emojis
# Out:
# {'😂': 5116,
#  '🔥': 3101,
#  '😱': 2992,
#  '❤': 2047,
#  '😍': 1907,
#  '🤣': 1770,
#  '😳': 1371,
#  '😭': 1260,
#  '🤯': 927,
#  '🙏': 839}

# %% [markdown]
# <br>
#
# ## 4. Video with the most days in the trend
# ___

# %%
days_in_trend = {}
for country in countries:
    df = COUNTRIES[country]

    # Group data
    data = (
        df.groupby(["channelTitles", "titles", "categoryNames"])
            .agg(todays_count=("today", "count"))
            .sort_values("todays_count", ascending=False)
            .reset_index()
    )

    # Which video has the most days on the trend page?
    max_todays_count = data["todays_count"].max()
    days = data[data["todays_count"] == max_todays_count].iloc[:1]
    days = days.to_dict(orient="records")
    days = [f"({v['categoryNames']}) {v['channelTitles']}: {v['titles']} for {v['todays_count']} days" for v in days][0]
    days_in_trend.update({country: days})

# Store & show results
ANALYSIS = ANALYSIS.assign(days_in_trend=lambda x: x["countries"].map(days_in_trend))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories  \
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}
#
#    origin_share  title_length  title_upper  emoji_share  \
# 0        76.700        50.100       22.600        4.000
# 1        91.800        55.000       45.100        9.000
# 2        67.600        57.800       30.700        8.700
# 3        95.200        37.900        8.000        4.000
# 4        92.100        68.400       16.600       26.000
# 5        41.300        52.400       23.100        5.600
# 6        72.000        55.700       22.700       15.600
# 7        86.900        51.800       29.800       10.800
# 8         7.000        50.600       22.500        4.600
# 9        16.100        50.000       22.800        4.900
#
#                         emoji_top3  \
# 0      {'😂': 86, '😳': 64, '😱': 52}
# 1   {'😱': 260, '😂': 226, '🔥': 166}
# 2   {'😱': 512, '⚡': 322, '🔥': 263}
# 3     {'‼': 128, '🔥': 60, '⁉': 59}
# 4  {'😂': 1323, '❤': 620, '🤣': 574}
# 5    {'🔥': 107, '😂': 103, '🤯': 79}
# 6   {'🔥': 487, '😂': 451, '😱': 447}
# 7   {'🔥': 154, '😂': 153, '😱': 153}
# 8     {'😂': 119, '😳': 73, '🔥': 60}
# 9      {'😂': 97, '🔥': 70, '😳': 57}
#
#                                                                                          days_in_trend
# 0                                          (Science & Technology) SpaceX: Starlink Mission for 25 days
# 1              (Music) Hungria Hip Hop: Hungria Hip Hop - Só era Nós (Official Music Video) for 6 days
# 2  (Nonprofits & Activism) Серебряный Дождь: Прямая трансляция  радиостанции "Серебряный Дождь" for...
# 3                                                (Entertainment) 動画アップロードチャンネル: 【押忍】報道について。 for 7 days
# 4  (People & Blogs) gogo 2728: An Emotional story 🥺❤️ | gogo2728 | deepesh_zo | mr_roshan | shubham...
# 5                                          (Science & Technology) SpaceX: Starlink Mission for 15 days
# 6                                           (Science & Technology) SpaceX: Starlink Mission for 7 days
# 7                                 (News & Politics) Emmanuel Macron: Adresse aux Français. for 10 days
# 8                                          (Science & Technology) SpaceX: Starlink Mission for 16 days
# 9                        (Entertainment) Beast Reacts: Extreme Try Not To Laugh Challenge! for 14 days

# %% [markdown]
# <br>
#
# ## 5. Most viewed videos (total & country of origin)
# ___

# %%
most_views = {}
most_views_coo = {}
for country in countries:
    df = COUNTRIES[country]

    # Which video has the most views?
    data = df[df["views"] == df["views"].max()]
    data = data.to_dict(orient="records")
    data = [f"({v['categoryNames']}) {v['channelTitles']}: {v['titles']} with {v['views']} views" for v in data][0]
    most_views.update({country: data})

    # Which video from the country of origin has the most views?
    data = df[df["channelCountry"] == country]
    data = data[data["views"] == data["views"].max()]
    data = data.to_dict(orient="records")
    data = [f"({v['categoryNames']}) {v['channelTitles']}: {v['titles']} with {v['views']} views" for v in data][0]
    most_views_coo.update({country: data})

# Store & show results
ANALYSIS = ANALYSIS.assign(most_views=lambda x: x["countries"].map(most_views))
ANALYSIS = ANALYSIS.assign(most_views_coo=lambda x: x["countries"].map(most_views_coo))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories  \
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}
#
#    origin_share  title_length  title_upper  emoji_share  \
# 0        76.700        50.100       22.600        4.000
# 1        91.800        55.000       45.100        9.000
# 2        67.600        57.800       30.700        8.700
# 3        95.200        37.900        8.000        4.000
# 4        92.100        68.400       16.600       26.000
# 5        41.300        52.400       23.100        5.600
# 6        72.000        55.700       22.700       15.600
# 7        86.900        51.800       29.800       10.800
# 8         7.000        50.600       22.500        4.600
# 9        16.100        50.000       22.800        4.900
#
#                         emoji_top3  \
# 0      {'😂': 86, '😳': 64, '😱': 52}
# 1   {'😱': 260, '😂': 226, '🔥': 166}
# 2   {'😱': 512, '⚡': 322, '🔥': 263}
# 3     {'‼': 128, '🔥': 60, '⁉': 59}
# 4  {'😂': 1323, '❤': 620, '🤣': 574}
# 5    {'🔥': 107, '😂': 103, '🤯': 79}
# 6   {'🔥': 487, '😂': 451, '😱': 447}
# 7   {'🔥': 154, '😂': 153, '😱': 153}
# 8     {'😂': 119, '😳': 73, '🔥': 60}
# 9      {'😂': 97, '🔥': 70, '😳': 57}
#
#                                                                                          days_in_trend  \
# 0                                          (Science & Technology) SpaceX: Starlink Mission for 25 days
# 1              (Music) Hungria Hip Hop: Hungria Hip Hop - Só era Nós (Official Music Video) for 6 days
# 2  (Nonprofits & Activism) Серебряный Дождь: Прямая трансляция  радиостанции "Серебряный Дождь" for...
# 3                                                (Entertainment) 動画アップロードチャンネル: 【押忍】報道について。 for 7 days
# 4  (People & Blogs) gogo 2728: An Emotional story 🥺❤️ | gogo2728 | deepesh_zo | mr_roshan | shubham...
# 5                                          (Science & Technology) SpaceX: Starlink Mission for 15 days
# 6                                           (Science & Technology) SpaceX: Starlink Mission for 7 days
# 7                                 (News & Politics) Emmanuel Macron: Adresse aux Français. for 10 days
# 8                                          (Science & Technology) SpaceX: Starlink Mission for 16 days
# 9                        (Entertainment) Beast Reacts: Extreme Try Not To Laugh Challenge! for 14 days
#
#                                                                      most_views  \
# 0  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189432443.0 views
# 1  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189432443.0 views
# 2  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 165977661.0 views
# 3  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 208865178.0 views
# 4  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 233425437.0 views
# 5  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 165977740.0 views
# 6  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 7  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 8  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 9  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 245528669.0 views
#
#                                                                                         most_views_coo
# 0                     (Entertainment) MrBeast: $456,000 Squid Game In Real Life! with 99337676.0 views
# 1  (Sports) CazéTV: JOGO COMPLETO: BRASIL X CROÁCIA | QUARTAS DE FINAL | COPA DO MUNDO 2022 with 31...
# 2                                         (Comedy) dednahype: 😱OMG😱 BEST TEACHER with 77344758.0 views
# 3      (Film & Animation) アニプレックス YouTube チャンネル: TVアニメ「鬼滅の刃」遊郭編 第1弾PV  2021年放送開始 with 12286506.0 views
# 4  (Music) DM - Desi Melodies: Filhaal2 Mohabbat | Akshay Kumar Ft Nupur Sanon | Ammy Virk | BPraak...
# 5  (News & Politics) Guardian News: Watch the uncensored moment Will Smith smacks Chris Rock on sta...
# 6                      (Comedy) Tsuriki Show: Guess the sound challenge🎵 #shorts with 58814660.0 views
# 7  (Sports) PSG - Paris Saint-Germain: #LEOMESSI: First steps and first training at the Ooredoo Cen...
# 8               (Comedy) Manchurek Triplets: Whipped Cream or Mustard? 🤣 #Shorts with 48668343.0 views
# 9              (Sports) How Ridiculous: Javelin Balloon Pop Racing Is INTENSE!! with 161580180.0 views

# %% [markdown]
# <br>
#
# ## 6. Most trending channels
# ___

# %%
trendiest_channel = {}
for country in countries:
    df = COUNTRIES[country]

    # Group data
    data = (
        df.groupby(["channelTitles", "titles", "publishedAt", "durations", "thumbnails", "categoryNames"])
            .agg(
                todays=("today", list),
                todays_count=("today", "count"),
                min_views=("views", "min"),
                max_views=("views", "max"),
                min_likes=("likes", "min"),
                max_likes=("likes", "max"),
                min_comments=("comments", "min"),
                max_comments=("comments", "max"),
                channelSubscriberCount=("channelSubscriberCount", "mean"),
                duration_in_s=("duration_in_s", "mean")
            )
            .sort_values("todays_count", ascending=False)
            .reset_index()
    )

    data = data.groupby("channelTitles").agg(
        count=("channelTitles", "count"),
        min_views=("min_views", "mean"),
        durations=("duration_in_s", "mean"),
        subcribers=("channelSubscriberCount", "mean"),
        days_in_trends=("todays_count", "sum"),
        categoryNames=("categoryNames", lambda x: x.value_counts().index[0])
    ).sort_values("count", ascending=False).head(50)
    data["durations"] = data["durations"] / 60
    data["avg_days_in_trends"] = data["days_in_trends"] / data["count"]
    data = data.rename(columns={"durations": "durations_in_min"})
    data = data.reset_index()
    data = data.round(0)

    # Want to see the plot?
    if show_plot:
        fig = px.scatter(
            data,
            x="count",
            y="days_in_trends",
            color="categoryNames",
            size="subcribers",
            labels={
                "count": "Number of videos",
                "days_in_trends": "Number of days in trends",
                "categoryNames": "Video category",
                "avg_days_in_trends": "Average number of days in trends",
                "durations_in_min": "Average duration of video in minutes",
                "min_views": "Average number of views",
                "subcribers": "Average number of subscribers"
            },
            title=f"{country}: Top 100 succesful channels",
            hover_name="channelTitles",
            hover_data=["durations_in_min"],
            size_max=40,
            color_discrete_map={
                "Film & Animation": "brown",
                "Autos & Vehicles": "lightblue",
                "Music": "green",
                "Pets & Animals": "black",
                "Sports": "grey",
                "Travel & Events": "yellow",
                "Gaming": "magenta",
                "People & Blogs": "orange",
                "Comedy": "purple",
                "Entertainment": "blue",
                "News & Politics": "red",
                "Howto & Style": "pink",
                "Education": "olive",
                "Science & Technology": "cyan",
                "Nonprofits & Activism": "lightgreen"
            }
        ).update_layout(height=600, width=1200).show()

    # Which channel has the most trending videos?
    max_trending_count = data["count"].max()
    data = data[data["count"] == max_trending_count].iloc[:1]
    data = data.to_dict(orient="records")
    data = [f"({v['categoryNames']}) {v['channelTitles']}: {v['count']} videos" for v in data][0]
    trendiest_channel.update({country: data})

# Store & show results
ANALYSIS = ANALYSIS.assign(trendiest_channel=lambda x: x["countries"].map(trendiest_channel))
ANALYSIS.head(10)
# Out:
#   countries  \
# 0        US
# 1        BR
# 2        RU
# 3        JP
# 4        IN
# 5        GB
# 6        DE
# 7        FR
# 8        CA
# 9        AU
#
#                                                             top3_categories  \
# 0                    {'Gaming': 21.1, 'Entertainment': 20.4, 'Music': 16.1}
# 1                    {'Entertainment': 24.8, 'Music': 21.2, 'Gaming': 15.1}
# 2  {'People & Blogs': 18.0, 'Entertainment': 16.8, 'News & Politics': 13.3}
# 3                    {'Entertainment': 32.7, 'Gaming': 16.1, 'Music': 13.5}
# 4            {'Entertainment': 35.8, 'People & Blogs': 19.0, 'Music': 13.7}
# 5                   {'Entertainment': 22.1, 'Sports': 18.6, 'Gaming': 17.9}
# 6                    {'Entertainment': 26.2, 'Music': 17.5, 'Sports': 12.4}
# 7                    {'Entertainment': 25.7, 'Music': 18.6, 'Gaming': 12.1}
# 8                    {'Entertainment': 21.7, 'Gaming': 20.9, 'Music': 12.7}
# 9                   {'Entertainment': 22.0, 'Gaming': 21.5, 'Sports': 14.3}
#
#    origin_share  title_length  title_upper  emoji_share  \
# 0        76.700        50.100       22.600        4.000
# 1        91.800        55.000       45.100        9.000
# 2        67.600        57.800       30.700        8.700
# 3        95.200        37.900        8.000        4.000
# 4        92.100        68.400       16.600       26.000
# 5        41.300        52.400       23.100        5.600
# 6        72.000        55.700       22.700       15.600
# 7        86.900        51.800       29.800       10.800
# 8         7.000        50.600       22.500        4.600
# 9        16.100        50.000       22.800        4.900
#
#                         emoji_top3  \
# 0      {'😂': 86, '😳': 64, '😱': 52}
# 1   {'😱': 260, '😂': 226, '🔥': 166}
# 2   {'😱': 512, '⚡': 322, '🔥': 263}
# 3     {'‼': 128, '🔥': 60, '⁉': 59}
# 4  {'😂': 1323, '❤': 620, '🤣': 574}
# 5    {'🔥': 107, '😂': 103, '🤯': 79}
# 6   {'🔥': 487, '😂': 451, '😱': 447}
# 7   {'🔥': 154, '😂': 153, '😱': 153}
# 8     {'😂': 119, '😳': 73, '🔥': 60}
# 9      {'😂': 97, '🔥': 70, '😳': 57}
#
#                                                                                          days_in_trend  \
# 0                                          (Science & Technology) SpaceX: Starlink Mission for 25 days
# 1              (Music) Hungria Hip Hop: Hungria Hip Hop - Só era Nós (Official Music Video) for 6 days
# 2  (Nonprofits & Activism) Серебряный Дождь: Прямая трансляция  радиостанции "Серебряный Дождь" for...
# 3                                                (Entertainment) 動画アップロードチャンネル: 【押忍】報道について。 for 7 days
# 4  (People & Blogs) gogo 2728: An Emotional story 🥺❤️ | gogo2728 | deepesh_zo | mr_roshan | shubham...
# 5                                          (Science & Technology) SpaceX: Starlink Mission for 15 days
# 6                                           (Science & Technology) SpaceX: Starlink Mission for 7 days
# 7                                 (News & Politics) Emmanuel Macron: Adresse aux Français. for 10 days
# 8                                          (Science & Technology) SpaceX: Starlink Mission for 16 days
# 9                        (Entertainment) Beast Reacts: Extreme Try Not To Laugh Challenge! for 14 days
#
#                                                                      most_views  \
# 0  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189432443.0 views
# 1  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189432443.0 views
# 2  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 165977661.0 views
# 3  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 208865178.0 views
# 4  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 233425437.0 views
# 5  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 165977740.0 views
# 6  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 7  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 8  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 189515569.0 views
# 9  (Music) HYBE LABELS: BTS (방탄소년단) 'Butter' Official MV with 245528669.0 views
#
#                                                                                         most_views_coo  \
# 0                     (Entertainment) MrBeast: $456,000 Squid Game In Real Life! with 99337676.0 views
# 1  (Sports) CazéTV: JOGO COMPLETO: BRASIL X CROÁCIA | QUARTAS DE FINAL | COPA DO MUNDO 2022 with 31...
# 2                                         (Comedy) dednahype: 😱OMG😱 BEST TEACHER with 77344758.0 views
# 3      (Film & Animation) アニプレックス YouTube チャンネル: TVアニメ「鬼滅の刃」遊郭編 第1弾PV  2021年放送開始 with 12286506.0 views
# 4  (Music) DM - Desi Melodies: Filhaal2 Mohabbat | Akshay Kumar Ft Nupur Sanon | Ammy Virk | BPraak...
# 5  (News & Politics) Guardian News: Watch the uncensored moment Will Smith smacks Chris Rock on sta...
# 6                      (Comedy) Tsuriki Show: Guess the sound challenge🎵 #shorts with 58814660.0 views
# 7  (Sports) PSG - Paris Saint-Germain: #LEOMESSI: First steps and first training at the Ooredoo Cen...
# 8               (Comedy) Manchurek Triplets: Whipped Cream or Mustard? 🤣 #Shorts with 48668343.0 views
# 9              (Sports) How Ridiculous: Javelin Balloon Pop Racing Is INTENSE!! with 161580180.0 views
#
#                                  trendiest_channel
# 0                         (Sports) NFL: 188 videos
# 1                          (Sports) ge: 539 videos
# 2                   (Entertainment) A4: 379 videos
# 3                      (Comedy) 東海オンエア: 402 videos
# 4  (People & Blogs) Sourav Joshi Vlogs: 266 videos
# 5         (Sports) Sky Sports Football: 478 videos
# 6    (Autos & Vehicles) JP Performance: 165 videos
# 7          (Sports) beIN SPORTS France: 388 videos
# 8                         (Sports) NBA: 124 videos
# 9                 (Sports) Optus Sport: 124 videos

# %% [markdown]
# <br>
#
# ## 7. Top 25 international videos and channels
# ___

# %%
# What are the 25 most popular international videos with the most trending days?
top25_videos = (
    pd.concat(COUNTRIES.values(), ignore_index=True)
    .groupby(["channelTitles", "titles", "publishedAt", "categoryNames"])
    .agg(todays_count=("today", "count"))
    .sort_values("todays_count", ascending=False)
    .reset_index()
    .drop(columns=["publishedAt"])
    .head(25)
)

top25_videos
# Out:
#            channelTitles  \
# 0            HYBE LABELS
# 1                   FIFA
# 2              BLACKPINK
# 3            HYBE LABELS
# 4            officialpsy
# 5            HYBE LABELS
# 6              BLACKPINK
# 7                    NFL
# 8            Linkin Park
# 9          Guardian News
# 10              Coldplay
# 11             AdeleVEVO
# 12                   NFL
# 13       TaylorSwiftVEVO
# 14     JYP Entertainment
# 15  Marvel Entertainment
# 16                   NFL
# 17           HYBE LABELS
# 18             BLACKPINK
# 19             BANGTANTV
# 20     JYP Entertainment
# 21          Charlie Puth
# 22           HYBE LABELS
# 23                   MTV
# 24              Coldplay
#
#                                                                                                  titles  \
# 0                                                                      BTS (방탄소년단) 'Butter' Official MV
# 1                             Jung Kook from BTS performs 'Dreamers' at FIFA World Cup opening ceremony
# 2                                                                          BLACKPINK - ‘Pink Venom’ M/V
# 3                                                         BTS (방탄소년단) 'Permission to Dance' Official MV
# 4                                                      PSY - 'That That (prod. & feat. SUGA of BTS)' MV
# 5                                     BTS (방탄소년단) 'Yet To Come (The Most Beautiful Moment)' Official MV
# 6                                                                           BLACKPINK - ‘Shut Down’ M/V
# 7   Dr. Dre, Snoop Dogg, Eminem, Mary J. Blige & Kendrick Lamar FULL Pepsi Super Bowl LVI Halftime Show
# 8                                                             Lost [Official Music Video] - Linkin Park
# 9         Watch the uncensored moment Will Smith smacks Chris Rock on stage at the Oscars, drops F-bomb
# 10                                                        Coldplay X BTS - My Universe (Official Video)
# 11                                                                  Adele - Easy On Me (Official Video)
# 12                                                  The Weeknd’s FULL Pepsi Super Bowl LV Halftime Show
# 13                                                      Taylor Swift - Anti-Hero (Official Music Video)
# 14                                              TWICE Pre-release english track "MOONLIGHT SUNRISE" M/V
# 15                                               Official Trailer | She-Hulk: Attorney at Law | Disney+
# 16                                             Rihanna’s FULL Apple Music Super Bowl LVII Halftime Show
# 17                                                        TXT (투모로우바이투게더) 'Sugar Rush Ride' Official MV
# 18                                                                           ROSÉ - 'On The Ground' M/V
# 19                                                        BTS (방탄소년단) 'Butter' @ Billboard Music Awards
# 20                                                                           TWICE "Talk that Talk" M/V
# 21                              Charlie Puth - Left And Right (feat. Jung Kook of BTS) [Official Video]
# 22                                                                  진 (Jin) 'The Astronaut' Official MV
# 23                                                          BLACKPINK Performs "Pink Venom" | 2022 VMAs
# 24                                                  Coldplay X BTS - My Universe (Official Lyric Video)
#
#       categoryNames  todays_count
# 0             Music            45
# 1            Sports            45
# 2             Music            44
# 3             Music            42
# 4             Music            42
# 5             Music            42
# 6             Music            40
# 7            Sports            40
# 8             Music            38
# 9   News & Politics            37
# 10            Music            36
# 11            Music            36
# 12           Sports            36
# 13            Music            36
# 14            Music            34
# 15    Entertainment            34
# 16           Sports            34
# 17            Music            33
# 18            Music            33
# 19            Music            33
# 20            Music            33
# 21            Music            33
# 22            Music            33
# 23    Entertainment            33
# 24            Music            32

# %%
# What are the 25 most popular international channels with the most trending days across all videos?
top25_channels = (
    pd.concat(COUNTRIES.values(), ignore_index=True)
    .groupby(["channelTitles", "titles", "publishedAt", "categoryNames"])
    .agg(todays_count=("today", "count"))
    .sort_values("todays_count", ascending=False)
    .reset_index()
    .groupby("channelTitles")
    .agg(
        count=("channelTitles", "count"),
        days_in_trends=("todays_count", "sum"),
        categoryNames=("categoryNames", lambda x: x.value_counts().index[0]))
    .sort_values("days_in_trends", ascending=False)
    .head(25)
)

top25_channels["avg_days_in_trends"] = top25_channels["days_in_trends"] / top25_channels["count"]
top25_channels.reset_index()
# Out:
#            channelTitles  count  days_in_trends  categoryNames  \
# 0            HYBE LABELS     86            1008          Music
# 1                 東海オンエア    402             947         Comedy
# 2                MrBeast     48             874  Entertainment
# 3                     ge    539             871         Sports
# 4      JYP Entertainment     75             780          Music
# 5                    NFL    197             756         Sports
# 6         Clash of Clans     57             754         Gaming
# 7                 SMTOWN     75             751          Music
# 8              FORMULA 1    141             748         Sports
# 9    Sky Sports Football    493             727         Sports
# 10  Marvel Entertainment     60             725  Entertainment
# 11                    A4    378             713  Entertainment
# 12          Dude Perfect     53             706         Sports
# 13             BANGTANTV    113             687          Music
# 14          Beast Reacts     77             673  Entertainment
# 15        MrBeast Gaming     45             656         Gaming
# 16              BT Sport    348             645         Sports
# 17           ESPN Brasil    391             638         Sports
# 18                   NBA    215             553         Sports
# 19              Problems    329             550         Gaming
# 20    beIN SPORTS France    390             546         Sports
# 21      The United Stand    260             539  Entertainment
# 22               Sidemen     79             533  Entertainment
# 23             BLACKPINK     48             529          Music
# 24            Veritasium     62             520      Education
#
#     avg_days_in_trends
# 0               11.721
# 1                2.356
# 2               18.208
# 3                1.616
# 4               10.400
# 5                3.838
# 6               13.228
# 7               10.013
# 8                5.305
# 9                1.475
# 10              12.083
# 11               1.886
# 12              13.321
# 13               6.080
# 14               8.740
# 15              14.578
# 16               1.853
# 17               1.632
# 18               2.572
# 19               1.672
# 20               1.400
# 21               2.073
# 22               6.747
# 23              11.021
# 24               8.387
